# %% [markdown]
# <a href="https://colab.research.google.com/github/MichelDVS/Apresentando-o-Pandas-em-Python/blob/master/Aula_de_Visualiza%C3%A7%C3%A3o_de_gr%C3%A1ficos_com_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df1 = pd.read_excel("Aracaju.xlsx")
df2 = pd.read_excel("Fortaleza.xlsx")
df3 = pd.read_excel("Natal.xlsx")
df4 = pd.read_excel("Recife.xlsx")
df5 = pd.read_excel("Salvador.xlsx")

# %%
df5.head()
# Out:
#      Cidade       Data  Vendas  LojaID  Qtde
# 0  Salvador 2018-01-01   31.06    1037     3
# 1  Salvador 2018-01-01   19.02    1034     3
# 2  Salvador 2019-02-10  173.59    1035     3
# 3  Salvador 2019-02-10  176.34    1037     3
# 4  Salvador 2019-02-14   19.47    1037     3

# %%
df= pd.concat([df1, df2, df3, df4, df5])

# %%
df.head()
# Out:
#     Cidade       Data  Vendas  LojaID  Qtde
# 0  Aracaju 2018-01-01  142.00    1520     1
# 1  Aracaju 2018-01-01   14.21    1522     6
# 2  Aracaju 2018-01-01   71.55    1520     1
# 3  Aracaju 2018-01-01    3.01    1521     7
# 4  Aracaju 2018-01-01   24.51    1522     8

# %%
df.tail()
# Out:
#        Cidade       Data  Vendas  LojaID  Qtde
# 235  Salvador 2019-01-03   41.84    1034     1
# 236  Salvador 2019-01-03  126.29    1035     3
# 237  Salvador 2019-01-03   38.06    1036     3
# 238  Salvador 2019-01-03  139.64    1035     1
# 239  Salvador 2019-01-03  161.41    1037     3

# %%
df.sample(5)
# Out:
#         Cidade       Data  Vendas  LojaID  Qtde
# 234   Salvador 2019-01-03   48.39    1035     2
# 80       Natal 2018-05-23  264.00     852     3
# 222   Salvador 2019-01-02   43.96    1037     1
# 132  Fortaleza 2019-03-02   17.49     983     5
# 60      Recife 2019-01-01   37.97     983     1

# %%
df.dtypes
# Out:
# Cidade            object
# Data      datetime64[ns]
# Vendas           float64
# LojaID            object
# Qtde               int64
# dtype: object

# %%
df["LojaID"] = df["LojaID"].astype("object")

# %%
df.isnull().sum()
# Out:
# Cidade    0
# Data      0
# Vendas    0
# LojaID    0
# Qtde      0
# dtype: int64

# %%
df["Receita"] = df["Vendas"].mul(df["Qtde"])

# %%
df.head()
# Out:
#     Cidade       Data  Vendas LojaID  Qtde  Receita
# 0  Aracaju 2018-01-01  142.00   1520     1   142.00
# 1  Aracaju 2018-01-01   14.21   1522     6    85.26
# 2  Aracaju 2018-01-01   71.55   1520     1    71.55
# 3  Aracaju 2018-01-01    3.01   1521     7    21.07
# 4  Aracaju 2018-01-01   24.51   1522     8   196.08

# %%
df.nlargest(3, "Receita")
# Out:
#    Cidade       Data  Vendas LojaID  Qtde  Receita
# 7   Natal 2019-03-18   886.0    853     4   3544.0
# 51  Natal 2018-01-21   859.0    852     4   3436.0
# 55  Natal 2019-01-08   859.0    854     4   3436.0

# %%
df.nsmallest(3, "Receita")
# Out:
#       Cidade       Data  Vendas LojaID  Qtde  Receita
# 118  Aracaju 2018-01-01    3.34   1522     1     3.34
# 65    Recife 2019-01-01    4.01    981     1     4.01
# 92     Natal 2019-01-02    4.57   1035     1     4.57

# %%
df.groupby("Cidade")["Receita"].sum()
# Out:
# Cidade
# Aracaju       48748.25
# Fortaleza     37913.97
# Natal        167227.52
# Recife        51936.51
# Salvador      40596.73
# Name: Receita, dtype: float64

# %%
df.sort_values("Receita", ascending=False).head(10)
# Out:
#    Cidade       Data  Vendas LojaID  Qtde  Receita
# 7   Natal 2019-03-18   886.0    853     4   3544.0
# 55  Natal 2019-01-08   859.0    854     4   3436.0
# 51  Natal 2018-01-21   859.0    852     4   3436.0
# 30  Natal 2018-10-02   856.0    853     4   3424.0
# 41  Natal 2018-05-20   835.0    852     4   3340.0
# 38  Natal 2018-02-25   828.0    852     4   3312.0
# 10  Natal 2018-10-27   828.0    852     4   3312.0
# 69  Natal 2019-03-24   817.0    852     4   3268.0
# 62  Natal 2018-02-10   793.0    854     4   3172.0
# 52  Natal 2018-04-27   778.0    854     4   3112.0

# %%
df = df.rename(columns={"Receita" : "Receita/Venda"})

# %%
df.head()
# Out:
#     Cidade       Data  Vendas LojaID  Qtde  Receita/Venda
# 0  Aracaju 2018-01-01  142.00   1520     1         142.00
# 1  Aracaju 2018-01-01   14.21   1522     6          85.26
# 2  Aracaju 2018-01-01   71.55   1520     1          71.55
# 3  Aracaju 2018-01-01    3.01   1521     7          21.07
# 4  Aracaju 2018-01-01   24.51   1522     8         196.08

# %%
df.shape
# Out:
# (894, 6)

# %%
df.tail()
# Out:
#        Cidade       Data  Vendas LojaID  Qtde  Receita/Venda
# 235  Salvador 2019-01-03   41.84   1034     1          41.84
# 236  Salvador 2019-01-03  126.29   1035     3         378.87
# 237  Salvador 2019-01-03   38.06   1036     3         114.18
# 238  Salvador 2019-01-03  139.64   1035     1         139.64
# 239  Salvador 2019-01-03  161.41   1037     3         484.23

# %%
df.dtypes
# Out:
# Cidade                   object
# Data             datetime64[ns]
# Vendas                  float64
# LojaID                   object
# Qtde                      int64
# Receita/Venda           float64
# dtype: object

# %%
df.groupby(df["data"].dt.year)["Receita/Venda"].sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'data'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df.head()
# Out:
#     Cidade       Data  Vendas LojaID  Qtde  Receita/Venda
# 0  Aracaju 2018-01-01  142.00   1520     1         142.00
# 1  Aracaju 2018-01-01   14.21   1522     6          85.26
# 2  Aracaju 2018-01-01   71.55   1520     1          71.55
# 3  Aracaju 2018-01-01    3.01   1521     7          21.07
# 4  Aracaju 2018-01-01   24.51   1522     8         196.08

# %%
df["Receita/Venda"].min()
# Out:
# 3.34

# %%
df.groupby(df["Data"].dt.year)["Receita/Venda"].sum()
# Out:
# Data
# 2018    118176.53
# 2019    228246.45
# Name: Receita/Venda, dtype: float64

# %%
df["Ano_Venda"] = df["Data"].dt.year

# %%
df.sample(5)
# Out:
#         Cidade       Data  Vendas LojaID  Qtde  Receita/Venda  Ano_Venda
# 138   Salvador 2019-03-02  212.03   1037     3         636.09       2019
# 102   Salvador 2019-01-01   40.84   1034     3         122.52       2019
# 43       Natal 2019-04-01  538.00    853     3        1614.00       2019
# 185   Salvador 2019-01-02    6.67   1036     1           6.67       2019
# 138  Fortaleza 2019-03-02  150.38    983     6         902.28       2019

# %%
df["Mes_Venda"], df["Dia_Venda"] = (df["Data"].dt.month, df["Data"].dt.day)

# %%
df.sample(5)
# Out:
#        Cidade       Data  Vendas LojaID  Qtde  Receita/Venda  Ano_Venda  \
# 56    Aracaju 2018-01-01   41.90   1523     6         251.40       2018
# 27      Natal 2018-07-16  390.00    853     3        1170.00       2018
# 36  Fortaleza 2019-01-01   36.31   1004     2          72.62       2019
# 37     Recife 2019-01-01  136.36    980     7         954.52       2019
# 6       Natal 2018-07-02  322.00    852     4        1288.00       2018
#
#     Mes_Venda  Dia_Venda
# 56          1          1
# 27          7         16
# 36          1          1
# 37          1          1
# 6           7          2

# %%
df["Diferenca_Dias"] = df["Data"] - df["Data"].min()

# %%
df.sample(5)
# Out:
#       Cidade       Data  Vendas LojaID  Qtde  Receita/Venda  Ano_Venda  \
# 24  Salvador 2019-01-01   15.60   1034     2          31.20       2019
# 18   Aracaju 2018-01-01   32.14   1522     6         192.84       2018
# 65   Aracaju 2018-01-01  145.54   1522     3         436.62       2018
# 2     Recife 2019-02-10   12.94    983     5          64.70       2019
# 17    Recife 2019-02-14  142.45    981     3         427.35       2019
#
#     Mes_Venda  Dia_Venda Diferenca_Dias
# 24          1          1       365 days
# 18          1          1         0 days
# 65          1          1         0 days
# 2           2         10       405 days
# 17          2         14       409 days

# %%
df["Trimestre_Venda"] = df["Data"].dt.quarter

# %%
df.sample(5)
# Out:
#         Cidade       Data  Vendas LojaID  Qtde  Receita/Venda  Ano_Venda  \
# 200      Natal 2019-01-02   41.06   1035     1          41.06       2019
# 124  Fortaleza 2019-03-02   47.98    983     7         335.86       2019
# 10   Fortaleza 2019-01-01  179.88   1002     4         719.52       2019
# 60   Fortaleza 2019-01-01  182.14   1002     4         728.56       2019
# 100     Recife 2019-01-01   35.11    982     4         140.44       2019
#
#      Mes_Venda  Dia_Venda Diferenca_Dias  Trimestre_Venda
# 200          1          2       366 days                1
# 124          3          2       425 days                1
# 10           1          1       365 days                1
# 60           1          1       365 days                1
# 100          1          1       365 days                1

# %%
df.sample(10)
# Out:
#         Cidade       Data  Vendas LojaID  Qtde  Receita/Venda  Ano_Venda  \
# 33   Fortaleza 2019-01-01   19.56   1005     1          19.56       2019
# 108      Natal 2019-01-02   11.72   1037     1          11.72       2019
# 57   Fortaleza 2019-01-01  129.07   1005     3         387.21       2019
# 61       Natal 2018-09-11  724.00    853     2        1448.00       2018
# 0        Natal 2018-08-27  606.00    853     2        1212.00       2018
# 95       Natal 2019-01-02    5.13   1035     1           5.13       2019
# 42    Salvador 2019-01-01   44.28   1034     1          44.28       2019
# 122  Fortaleza 2019-03-02  235.06    983     3         705.18       2019
# 62   Fortaleza 2019-01-01  106.21   1005     6         637.26       2019
# 209      Natal 2019-01-02   69.98   1034     2         139.96       2019
#
#      Mes_Venda  Dia_Venda Diferenca_Dias  Trimestre_Venda
# 33           1          1       365 days                1
# ...

# %%
df["LojaID"].value_counts(ascending=False)
# Out:
# 1036    117
# 1035    112
# 1037    101
# 1034     67
# 983      65
# 982      44
# 1522     41
# 1520     39
# 980      36
# 981      31
# 1005     30
# 1002     30
# 852      29
# 1523     29
# 1004     28
# 854      28
# 853      26
# 1521     21
# 1003     20
# Name: LojaID, dtype: int64

# %%
df["LojaID"].value_counts(ascending=False).plot.bar()

# %%
df["LojaID"].value_counts().plot.barh()

# %%
df["LojaID"].value_counts(ascending=True).plot.bar()

# %%
df["LojaID"].value_counts(ascending=False).plot.barh()

# %%
df["LojaID"].value_counts(ascending=False).plot.bar();

# %%
df["LojaID"].value_counts(ascending=False).plot.barh();

# %%
df.groupby(df["Data"].dt.year)["Receita/Venda"].sum().plot.pie();

# %%
df["Cidade"].value_counts()
# Out:
# Natal        240
# Salvador     240
# Fortaleza    142
# Recife       142
# Aracaju      130
# Name: Cidade, dtype: int64

# %%
import matplotlib.pyplot as plt
df["Cidade"].value_counts().plot.bar(title="Total vendas por Cidade")
plt.xlabel("Cidade")
plt.ylabel("Total Vendas");

# %%
plt.style.use("ggplot")

# %%
df.groupby(df["Mes_Venda"])["Qtde"].sum().plot(title = "Total Produtos vendidos por mes");
plt.xlabel("Mes")
plt.ylabel("Total de Produtos vendidos");
plt.legend()

# %%
df.groupby(df["Mes_Venda"])["Qtde"].sum()
# Out:
# Mes_Venda
# 1     2208
# 2      144
# 3      467
# 4       23
# 5       17
# 6       13
# 7       13
# 8        2
# 9       10
# 10      14
# 11       2
# 12       3
# Name: Qtde, dtype: int64
